# %%
import pandas as pd
import matplotlib.pyplot as plt

FILEPATH = "data/unknown_data.csv"

df = pd.read_csv(FILEPATH, header=None)
df.describe()
# Out:
#                0           1           2           3           4           5   \
# count   20.000000   20.000000   20.000000   20.000000   20.000000   20.000000
# mean    96.700000   90.600000  138.033333  131.363725  120.445098  107.097059
# std     30.740167   30.913121   69.945869   69.465671   51.434731   54.224710
# min     54.000000   52.000000   64.000000   50.000000   57.000000   57.000000
# 25%     71.250000   68.750000   83.500000   88.000000   88.500000   66.500000
# 50%     91.500000   79.000000  123.892157  107.245098  109.000000   88.000000
# 75%    125.000000  107.250000  161.735294  147.142157  139.500000  133.000000
# max    147.000000  145.000000  291.960784  285.529412  256.627451  268.294118
#
#                6           7           8           9   ...          40  \
# count   20.000000   20.000000   20.000000   20.000000  ...   20.000000
# mean   128.898039  157.342157  103.967647  103.050000  ...   98.050000
# ...

# %%
fig, ax = plt.subplots()
x = range(df.shape[1])
ax.stackplot(x, df)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.imshow(df)
plt.axis("off")
plt.colorbar(label="Intensity")

plt.show()
